# %%
# Variables
a = 10
b = 20
print(a + b)

# Data Types
name = "Shivania"
age = 21

# Loop
for i in range(5):
    print(i)

# Function
def add(x, y):
    return x + y

print(add(5, 3))
# Out:
# 30
# 0
# 1
# 2
# 3
# 4
# 8
